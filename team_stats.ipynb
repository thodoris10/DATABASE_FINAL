# %% [markdown]
# ## READ THE DATASET

# %%
import pandas as pd
data1=pd.read_csv('PLAYER_REGULAR2324.csv')
print(data1)
# Out:
#      Unnamed: 0                     NAME TEAM POS   AGE  GP   MPG  USG%  FTA  \
# 0             0              Joel Embiid  Phi   C  30.1  39  33.6  39.6  452
# 1             1              Luka Doncic  Dal   G  25.1  70  37.5  36.0  608
# 2             2    Giannis Antetokounmpo  Mil   F  29.4  73  35.2  33.0  782
# 3             3  Shai Gilgeous-Alexander  Okc   G  25.8  75  34.0  32.9  649
# 4             4            Jalen Brunson  Nyk   G  27.6  77  35.4  32.5  497
# ..          ...                      ...  ...  ..   ...  ..   ...   ...  ...
# 652         652           Justin Jackson  Min   F  29.1   2   0.4   0.0    0
# 653         653           Jalen Crutcher  Nor   G  24.7   1   2.7  16.1    0
# 654         654              Andrew Funk  Chi   G  24.6   5   2.7  13.1    0
# 655         655            Jacob Gilyard  Bro   G  25.8   4  11.2   6.8    0
# 656         656           Mamadi Diakite  Nyk   F  27.2   3   2.8  10.2    0
#
# ...

# %%
data1['TEAM'].value_counts()
# Out:
# TEAM
# Mem    33
# Det    31
# Tor    30
# Phi    28
# Nyk    26
# Cha    26
# Was    24
# Dal    22
# Ind    22
# Okc    22
# Pho    22
# Por    22
# Bro    21
# Uta    21
# Lac    21
# Mia    21
# Lal    21
# Mil    21
# Nor    20
# Sac    20
# San    20
# Atl    19
# Min    19
# Bos    19
# Gol    18
# Orl    18
# Cle    18
# Chi    18
# Den    17
# Hou    17
# Name: count, dtype: int64

# %% [markdown]
# ## DROP UNECESSARY ATTRIBUTES

# %%
columns_drop = ['rSOS','SOS','eWIN%','A4F','SAR','RANK','CONS']
data1.drop(columns_drop,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/px/m2vm_qc55yd4gkdnl89j1phc0000gn/T/ipykernel_54167/1849858007.py in <module>
#       1 columns_drop = ['rSOS','SOS','eWIN%','A4F','SAR','RANK','CONS']
# ----> 2 data1.drop(columns_drop,axis=1,inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# ...

# %%
print(data1)
# Out:
#     Unnamed: 0           TEAM  CONF   DIVISION  GP  PPG  oPPG  pDIFF  PACE  \
# 0            0      Cleveland  East    Central   1   97    83     14  96.3
# 1            1       New York  East   Atlantic   1  111   104      7  87.8
# 2            2      Milwaukee  East    Central   1  109    94     15  97.9
# 3            3         Boston  East   Atlantic   1  114    94     20  88.1
# 4            4        Orlando  East  Southeast   1   83    97    -14  96.3
# 5            5   Philadelphia  East   Atlantic   1  104   111     -7  87.8
# 6            6        Indiana  East    Central   1   94   109    -15  97.9
# 7            7          Miami  East  Southeast   1   94   114    -20  88.1
# 8            8      Minnesota  West  Northwest   1  120    95     25  96.2
# 9            9         Denver  West  Northwest   1  114   103     11  92.3
# 10          10    LA Clippers  West    Pacific   1  109    97     12  93.2
# ...

# %%
data1
# Out:
#              TEAM  CONF   DIVISION  GP  PPG  oPPG  pDIFF  PACE   oEFF   dEFF  \
# 0       Cleveland  East    Central   1   97    83     14  96.3  100.7   86.2
# 1        New York  East   Atlantic   1  111   104      7  87.8  126.4  118.4
# 2       Milwaukee  East    Central   1  109    94     15  97.9  111.3   96.0
# 3          Boston  East   Atlantic   1  114    94     20  88.1  129.5  106.8
# 4         Orlando  East  Southeast   1   83    97    -14  96.3   86.2  100.7
# 5    Philadelphia  East   Atlantic   1  104   111     -7  87.8  118.4  126.4
# 6         Indiana  East    Central   1   94   109    -15  97.9   96.0  111.3
# 7           Miami  East  Southeast   1   94   114    -20  88.1  106.8  129.5
# 8       Minnesota  West  Northwest   1  120    95     25  96.2  124.7   98.7
# 9          Denver  West  Northwest   1  114   103     11  92.3  123.5  111.6
# 10    LA Clippers  West    Pacific   1  109    97     12  93.2  117.4  104.5
# ...

# %%
data1.isna().sum()
# Out:
# TEAM        0
# CONF        0
# DIVISION    0
# GP          0
# PPG         0
# oPPG        0
# pDIFF       0
# PACE        0
# oEFF        0
# dEFF        0
# eDIFF       0
# W           0
# L           0
# WIN%        0
# pWIN%       0
# ACH         0
# STRK        0
# dtype: int64

# %% [markdown]
# ## CREATE PATH FOR FINAL DATASET

# %%
path='/Users/paterosthodoris/Desktop/STAT/SPRING_2024/STAT_6289/Final_Project/DATA/TEAM_PLAYOFF2324.csv'
data1.to_csv(path,index=1)

# %%
import pandas as pd
data1=pd.read_csv('TEAM_PLAYOFF2324.csv')
print(data1)
